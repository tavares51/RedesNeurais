# %% [markdown]
# #Importação das Bibliotecas

# %%
# -*- coding: utf-8 -*-

import numpy as np  # importa a biblioteca usada para trabalhar com vetores e matrizes
import pandas as pd # importa a biblioteca usada para trabalhar com dataframes (dados em formato de tabela) e análise de dados
import os # importa a biblioteca para tarefas relacionadas ao sistema operacional
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
import matplotlib as plt

# %%
train = pd.read_csv("dados/train.csv")

# %%
train.head()
# Out:
#    Id  Class
# 0  11     -1
# 1  23     -1
# 2  24     -1
# 3  30     -1
# 4  31     -1

# %%
def removeZero(df):
    df_sem_zero = df.loc[df['Class'] != 0]
    return df_sem_zero

# %%
def removeNulos(df):
    df.fillna(df.mean(), inplace=True)
    return df

# %%
def removeRedundantes(df):
    colunas_duplicadas = df.T.duplicated()
    df_sem_duplicatas = df.loc[:, ~colunas_duplicadas]
    return df_sem_duplicatas

# %%
def removeValoresRepetidos(df):
    colunas_repetidas = df.columns[df.columns.duplicated()].tolist()
    df_sem_repetidos = df.drop(columns=colunas_repetidas)
    return df_sem_repetidos

# %%
def preProcessamento(df):
    df = removeZero(df)
    df = removeNulos(df)
    df = removeRedundantes(df)
    df = removeValoresRepetidos(df)
    df.Class.replace(-1, 0, inplace=True)
    return df

# %%
def simplifica(df):

# %% [markdown]
# #Set 1

# %%
set1 = pd.read_csv("dados/set1.csv")
set1.head()
# Out:
#    Id  D0000     D0001     D0002        D0003        D0004      D0005  \
# 0   0    1.0  1.400000  1.400000     9.000000     9.000000   8.384615
# 1   1    0.0  0.723971  1.000000     9.000000     8.900000  34.294117
# 2   2    1.0  1.305677  1.305677    18.705883    18.705883  15.863636
# 3   3    0.0  5.141328  9.170616     1.000000     2.595238   7.166667
# 4   4    1.0  0.113582  0.113582  1137.434814  1137.434814   6.600000
#
#        D0006  D0007  D0008  ...         D0040  D0041  D0042    D0043  D0044  \
# 0   8.384615   13.0   13.0  ...  6.565851e-09   12.0   20.0  0.00001   32.0
# 1   9.222222   17.0    9.0  ...  3.488140e-09   10.0   29.0  0.00001   32.0
# 2  15.863636   22.0   22.0  ...  3.507373e-09   23.0   14.0  0.00001   32.0
# 3   3.886364   48.0   44.0  ...  3.094160e-08  113.0   15.0  0.00001   32.0
# 4   6.600000   40.0   40.0  ...  1.251197e-05   42.0   25.0  0.00001   32.0
#
#          D0045  D0046  D0047   D0048         D0049
# ...

# %%
set1.shape
# Out:
# (35441, 51)

# %%
df_set1 = pd.merge(set1, train, on='Id')

# %%
df_set1_processado = preProcessamento(df_set1)
# Out:
# <ipython-input-6-37642a597fac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(), inplace=True)

# %%
df_set1_processado.shape
# Out:
# (2523, 50)

# %% [markdown]
# # Set 2

# %%
set2 = pd.read_csv("dados/set2.csv")
set2.head()
# Out:
#    Id  D0000  D0001     D0002     D0003     D0004     D0005     D0006  \
# 0   0  146.0      4  4.205479  0.095890  0.027402  1.953728  0.054795
# 1   1   29.0     10  5.655172  0.379310  0.008225  1.429630  0.172414
# 2   2  163.0      8  5.300613  0.104294  0.018947  1.919626  0.141104
# 3   3   12.0      8  8.166667  0.416667  0.004304  1.392405  0.083333
# 4   4  250.0      7  5.432000  0.108000  0.014578  2.458716  0.160000
#
#       D0007     D0008  ...    D0098  D0099     D0100     D0101     D0102  \
# 0  0.089041  0.143836  ...  0.00001 -15.34  0.030143  0.158219  0.105479
# 1  0.275862  0.448276  ...  0.00001 -15.34  0.009047  0.493103  0.120168
# 2  0.184049  0.251534  ...  0.00001 -15.34  0.020842  0.276687  0.114724
# 3  0.166667  0.250000  ...  0.00001 -15.34  0.004735  0.275000  0.000000
# 4  0.252000  0.324000  ...  0.00001 -15.34  0.016036  0.356400  0.118800
#
#       D0103     D0104     D0105     D0106  D0107
# 0  0.033458  0.000117  0.191781  0.002603   0.08
# ...

# %%
set2.shape
# Out:
# (10290, 109)

# %%
df_set2 = train.merge(set2, on='Id', how = 'left')

# %%
df_set2_processado = preProcessamento(df_set2)
# Out:
# <ipython-input-6-37642a597fac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(), inplace=True)

# %%
df_set2_processado.shape
# Out:
# (4310, 107)

# %% [markdown]
# # Set 3

# %%
set3 = pd.read_csv("dados/set3.csv")
set3.head()
# Out:
#    Id     D0000     D0001     D0002     D0003     D0004     D0005     D0006  \
# 0   0  2.564949  2.564949  2.079442  2.079442  1.000000  1.000000  0.336472
# 1   1  2.833213  2.197225  2.197225  2.197225  0.333333  1.000000 -0.323004
# 2   2  3.091042  3.091042  2.833213  2.833213  0.941176  0.941176  0.266722
# 3   3  3.871201  3.784190  0.000000  3.737670  0.000000  0.976190  1.637311
# 4   4  3.688879  3.688879  3.135494  3.135494  0.652174  0.652174 -2.175233
#
#       D0007     D0008  ...  D0138  D0139    D0140     D0141     D0142  \
# 0  0.336472  2.197225  ...  0.024  0.040  0.00001  2.180207  0.850000
# 1  0.000000  2.197225  ...  0.020  0.058  0.00001  1.867641  0.850000
# 2  0.266722  2.928838  ...  0.046  0.028  0.00001  2.627386  0.800000
# 3  2.216004  0.000000  ...  0.226  0.030  0.00001  3.216561  0.829762
# 4 -2.175233  7.036531  ...  0.084  0.050  0.00001  3.135548  0.554348
#
#        D0143     D0144     D0145      D0146     D0147
# ...

# %%
set3.shape
# Out:
# (6748, 149)

# %%
df_set3 = pd.merge(set3, train, on='Id')

# %%
df_set3_processado = preProcessamento(df_set3)
# Out:
# <ipython-input-6-37642a597fac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(), inplace=True)

# %%
df_set3_processado.shape
# Out:
# (474, 149)

# %% [markdown]
# # Set total: set2 + set3

# %%
train = train.merge(set2, on='Id', how = 'left')
train = train.merge(set3,  on='Id', how = 'left')
train.Class.value_counts()
# Out:
# -1    4038
#  1     272
#  0     254
# Name: Class, dtype: int64

# %%
df_set_processado = preProcessamento(train)
# Out:
# <ipython-input-6-37642a597fac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(), inplace=True)

# %%
df_set_processado.shape
# Out:
# (4310, 253)

# %%
df_set_processado
# Out:
#          Id  Class     D0000_x    D0001_x   D0002_x   D0003_x   D0004_x  \
# 0        11      0  665.000000  22.000000  3.870677  2.562406  0.070125
# 1        23      0  193.000000   7.000000  6.186528  0.295337  0.010564
# 2        24      0    6.000000   6.000000  7.166667  0.000000  0.005854
# 3        30      0  358.000000   8.000000  4.600559  0.000000  0.025065
# 4        31      0  406.000000   2.000000  4.495074  0.032020  0.044284
# ...     ...    ...         ...        ...       ...       ...       ...
# 4559  60760      0  353.420054   6.001355  5.035496  0.291790  0.046344
# 4560  60765      0  353.420054   6.001355  5.035496  0.291790  0.046344
# 4561  60802      0  353.420054   6.001355  5.035496  0.291790  0.046344
# 4562  60814      0  353.420054   6.001355  5.035496  0.291790  0.046344
# 4563  60840      0  353.420054   6.001355  5.035496  0.291790  0.046344
#
#        D0005_x   D0006_x   D0007_x  ...       D0136       D0137      D0138  \
# ...

# %% [markdown]
# # Exportação dados

# %%
df_set1_processado.to_csv('set1_processado.csv', index=False)

# %%
df_set2_processado.to_csv('set2_processado.csv', index=False)

# %%
df_set3_processado.to_csv('set3_processado.csv', index=False)

# %%
df_set_processado.to_csv('set_processado.csv', index=False)
